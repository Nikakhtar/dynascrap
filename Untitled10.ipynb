# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikakhtar/dynascrap/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install dependencies
# !pip install scrapy
# !pip install nest-asyncio
# !pip install scrapy-user-agents
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
#Fix Google Colab’s Async Issues
import nest_asyncio
nest_asyncio.apply()

# %%
#Define Article Attributes
class ArticleItem:
    def __init__(self, title="", author="", source_name="", summary="",
                 content="", subject="", tags=[], main_pic="", publish_date="", url=""):
        self.article_title = title
        self.article_author = author
        self.article_source_name = source_name
        self.article_summary = summary
        self.article_content = content
        self.article_subject = subject
        self.article_tags = tags
        self.article_main_pic = main_pic
        self.article_publish_date = publish_date
        self.article_url = url

# %%
#Define Dynamic Scraping Rules
website_url = "https://www.bbc.co.uk/news"
scraping_rules = json.dumps({
    "article_title": "h1::text",
        "article_author": "span[data-testid='byline-name']::text",
        "article_source_name": "meta[property='og:site_name']::attr(content)",
        "article_summary": "p[class*='summary']::text",
        "article_content": "div[data-component='text-block'] p::text",
        "article_subject": "a[class*='section-link']::text",
        "article_tags": "li[class*='tags-list__tags'] a::text",
        "article_main_pic": "figure img::attr(src)",
        "article_publish_date": "time::attr(datetime)"
})
search_keyword = " iran"

# %%
#Define Dynamic Scraping Rules
website_url = "http://178.252.141.89:8432/newsportal"
scraping_rules = json.dumps({
    "article_title": "div.MuiBox-root.mui-98bx94 > div.MuiBox-root.mui-1tykiii > span.MuiTypography-root.MuiTypography-subtitle1Medium.line-clamp-2.mui-dp1w42::text"
})
search_keyword = " iran"

# %%
#Implement the Dynamic Spider
import scrapy
from scrapy.crawler import CrawlerProcess
import json

class DynamicNewsSpider(scrapy.Spider):
    name = "dynascrap_news"

    def __init__(self, website_url="", rules_json="", search_keyword="", *args, **kwargs):
        super(DynamicNewsSpider, self).__init__(*args, **kwargs)
        self.start_urls = [website_url]
        self.search_keyword = search_keyword
        self.rules = json.loads(rules_json)

    def parse(self, response):
        article = {}

        for key, selector in self.rules.items():
            article[key] = response.css(selector).get()

        article['article_url'] = response.url
        yield article

# %%
from scrapy.utils.project import get_project_settings
process = CrawlerProcess(get_project_settings())

process.crawl(DynamicNewsSpider, website_url=website_url, rules_json=scraping_rules, search_keyword=search_keyword)
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.12.0 started (bot: scrapybot)
# 2025-02-10 03:03:01 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2025-02-10 03:03:01 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2025-02-10 03:03:01 [scrapy.addons] INFO: Enabled addons:
# []
# DEBUG:scrapy.utils.log:Using reactor: twisted.internet.epollreactor.EPollReactor
# ...

# %%
import pandas as pd

df = pd.read_json("articles.json")
df.to_csv("articles.csv", index=False)  # Save to CSV
df.head()  # Display first 5 rows
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2025-02-10 02:02:20 [numexpr.utils] INFO: NumExpr defaulting to 2 threads.
# Empty DataFrame
# Columns: []
# Index: []
