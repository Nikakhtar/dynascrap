# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikakhtar/dynascrap/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install dependencies
# !pip install scrapy
# !pip install nest-asyncio
# !pip install scrapy-user-agents
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 48.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
#Fix Google Colab’s Async Issues
import nest_asyncio
nest_asyncio.apply()

# %%
#Define Dynamic Scraping Rules
import json
website_url = "https://www.google.com/search?q=news+website&newwindow=1&sca_esv=b4142faa2c6a62b4&sxsrf=AHTn8zpIJyequmPx73jQcImdVTkDLMvyXw%3A1739154825274&source=hp&ei=iWWpZ8feDYWWhbIPk4-DiAM&iflsig=ACkRmUkAAAAAZ6lzme9BY-PJ1HS61pwwz04xFtlEHH6H&ved=0ahUKEwiHx8TMiLiLAxUFS0EAHZPHADEQ4dUDCBk&uact=5&oq=news+website&gs_lp=Egdnd3Mtd2l6IgxuZXdzIHdlYnNpdGUyCxAAGIAEGJECGIoFMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAESLocUABYpxtwAHgAkAEAmAG-AqAB3hOqAQcwLjQuNi4xuAEDyAEA-&sclient=gws-wiz"
scraping_rules = json.dumps({
    "article_title": "h3.LC20lb.MBeuO.DKV0Md::text"
})
search_keyword = " iran"

# %%
#Implement the Dynamic Spider
import scrapy
from scrapy.crawler import CrawlerProcess
import json

class DynamicNewsSpider(scrapy.Spider):
    name = "dynascrap_news"

    def __init__(self, website_url="", rules_json="", search_keyword="", *args, **kwargs):
        super(DynamicNewsSpider, self).__init__(*args, **kwargs)
        self.start_urls = [website_url]
        self.search_keyword = search_keyword
        self.rules = json.loads(rules_json)

    custom_settings = {
        'FEEDS': {
            'articles.json': {'format': 'json'}
        }
    }

    def parse(self, response):
        article = {}

        for key, selector in self.rules.items():
            article[key] = response.css(selector).get()

        article['article_url'] = response.url
        yield article

# %%
from scrapy.utils.project import get_project_settings
process = CrawlerProcess(get_project_settings())

process.crawl(DynamicNewsSpider, website_url=website_url, rules_json=scraping_rules, search_keyword=search_keyword)
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.12.0 started (bot: scrapybot)
# 2025-02-10 04:39:12 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2025-02-10 04:39:12 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2025-02-10 04:39:12 [scrapy.addons] INFO: Enabled addons:
# []
# DEBUG:scrapy.utils.log:Using reactor: twisted.internet.epollreactor.EPollReactor
# ...

# %%
import pandas as pd

df = pd.read_json("articles.json")
df.to_csv("articles.csv", index=False)  # Save to CSV
df.head()  # Display first 5 rows
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2025-02-10 04:39:22 [numexpr.utils] INFO: NumExpr defaulting to 2 threads.
#    article_title                                        article_url
# 0            NaN  https://www.google.com/search?q=news+website&n...
